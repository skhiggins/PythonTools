# %% [markdown]
# ### Step 1: Install from https://chromedriver.storage.googleapis.com/index.html?path=2.41/

# %% [markdown]
# ### Step 2: Tell where it's installed

# %%
import time
from selenium import webdriver

# %%
driver = webdriver.Chrome('C:/Dropbox/Programs/chromedriver')  # Optional argument, if not specified will search path.
driver.get('http://www.google.com/xhtml')
print("got driver")
time.sleep(5) # Let the user actually see something!
search_box = driver.find_element_by_name('q')
search_box.send_keys('ChromeDriver')
search_box.submit()
time.sleep(5) # Let the user actually see something!
driver.quit()
print("done")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# C:\Dropbox\Python3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# C:\Dropbox\Python3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     708                                 errread, errwrite,
# --> 709                                 restore_signals, start_new_session)
#     710         except:
#
# ...
